# %% [markdown]
# ### Lets Go with Python Baby !

# %%
# !python --version
# Out:
# Python 3.13.5

# %%
print("hi")
# Out:
# hi

# %%
name='sai'
Name='Harsha'
#name != Name
print(name)
print(Name)
# Out:
# sai
# Harsha

# %% [markdown]
# Indentation and Line Continuation

# %%
if True:
    print('HI')

total=1+2+3+\
4+5
print(total)
# Out:
# HI
# 15

# %% [markdown]
# Multiple statements in a single line

# %%
x=5;y=2;z=x+y;print(z)
# Out:
# 7

# %% [markdown]
# Variables in PYTHON

# %%
age=10
name="sai"
print(type(age))
print(type(name))
name=True
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
